# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Loan_default_Preprocessing.csv')
df.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio  Education  ...  LoanPurpose_Business  \
# 0         15.23        36      0.44          1  ...                 False
# 1          4.81        60      0.68          2  ...                 False
# 2         21.17        24      0.31          2  ...                 False
# 3          7.07        24      0.23          0  ...                  True
# 4          6.51        48      0.73          1  ...                 False
#
#    LoanPurpose_Education  LoanPurpose_Home  LoanPurpose_Other  HasMortgage_No  \
# 0                  False             False               True           False
# 1                  False             False               True            True
# 2                  False             False              False           False
# 3                  False             False              False            True
# 4                  False             False              False            True
#
#    HasMortgage_Yes  HasDependents_No  HasDependents_Yes  HasCoSigner_No  \
# 0             True             False               True           False
# 1            False              True              False           False
# 2             True             False               True            True
# 3            False              True              False            True
# 4            False             False               True            True
#
#    HasCoSigner_Yes
# 0             True
# 1             True
# 2            False
# 3            False
# 4            False
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Age                           255347 non-null  int64
#  1   Income                        255347 non-null  int64
#  2   LoanAmount                    255347 non-null  int64
#  3   CreditScore                   255347 non-null  int64
#  4   MonthsEmployed                255347 non-null  int64
#  5   NumCreditLines                255347 non-null  int64
#  6   InterestRate                  255347 non-null  float64
#  7   LoanTerm                      255347 non-null  int64
#  8   DTIRatio                      255347 non-null  float64
#  9   Education                     255347 non-null  int64
#  10  Default                       255347 non-null  int64
#  11  EmploymentType_Full-time      255347 non-null  bool
#  12  EmploymentType_Part-time      255347 non-null  bool
#  13  EmploymentType_Self-employed  255347 non-null  bool
#  14  EmploymentType_Unemployed     255347 non-null  bool
#  15  MaritalStatus_Divorced        255347 non-null  bool
#  16  MaritalStatus_Married         255347 non-null  bool
#  17  MaritalStatus_Single          255347 non-null  bool
#  18  LoanPurpose_Auto              255347 non-null  bool
#  19  LoanPurpose_Business          255347 non-null  bool
#  20  LoanPurpose_Education         255347 non-null  bool
#  21  LoanPurpose_Home              255347 non-null  bool
#  22  LoanPurpose_Other             255347 non-null  bool
#  23  HasMortgage_No                255347 non-null  bool
#  24  HasMortgage_Yes               255347 non-null  bool
#  25  HasDependents_No              255347 non-null  bool
#  26  HasDependents_Yes             255347 non-null  bool
#  27  HasCoSigner_No                255347 non-null  bool
#  28  HasCoSigner_Yes               255347 non-null  bool
# dtypes: bool(18), float64(2), int64(9)
# memory usage: 25.8 MB

# %%
X=df_ohe.drop('Default',axis=1)
Y=df_ohe['Default']
X.shape , Y.shape
# Out:
# ((255347, 29), (255347,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=7,stratify = Y)

# %% [markdown]
# """# **Getting Feature importance**
#
# # APPLY DECISION TREE
# """

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state = 7)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=7)

# %%
# importance of all features
sorted(zip(dt.feature_importances_,X_train.columns),reverse = True)
# Out:
# [(np.float64(0.1221538187342497), 'Income'),
#  (np.float64(0.12089658671551835), 'LoanAmount'),
#  (np.float64(0.11359213652591019), 'InterestRate'),
#  (np.float64(0.09934763957418692), 'LoanID'),
#  (np.float64(0.09285585242591118), 'CreditScore'),
#  (np.float64(0.08415808780421537), 'MonthsEmployed'),
#  (np.float64(0.07568019955061366), 'DTIRatio'),
#  (np.float64(0.0752965616345267), 'Age'),
#  (np.float64(0.028752039949372712), 'LoanTerm'),
#  (np.float64(0.025425948379092525), 'Education'),
#  (np.float64(0.02475718353670561), 'NumCreditLines'),
#  (np.float64(0.009022231293263136), 'EmploymentType_Unemployed'),
#  (np.float64(0.008703775238067193), 'LoanPurpose_Education'),
#  (np.float64(0.008630803559652019), 'LoanPurpose_Home'),
#  (np.float64(0.008588727352280966), 'EmploymentType_Part-time'),
#  (np.float64(0.008545146029686932), 'LoanPurpose_Business'),
#  (np.float64(0.008508844183329832), 'EmploymentType_Self-employed'),
#  (np.float64(0.008413959228606983), 'LoanPurpose_Auto'),
#  (np.float64(0.008358153360763869), 'LoanPurpose_Other'),
#  (np.float64(0.008074603072087292), 'EmploymentType_Full-time'),
#  (np.float64(0.008038472330665519), 'MaritalStatus_Single'),
#  (np.float64(0.007649090456169132), 'MaritalStatus_Divorced'),
#  (np.float64(0.007159791955919994), 'MaritalStatus_Married'),
#  (np.float64(0.007029638907642977), 'HasMortgage_No'),
#  (np.float64(0.006885058946538381), 'HasDependents_No'),
#  (np.float64(0.006767808893575836), 'HasMortgage_Yes'),
#  (np.float64(0.005690958777937026), 'HasCoSigner_No'),
#  (np.float64(0.0056471878421743855), 'HasDependents_Yes'),
#  (np.float64(0.005369693741335533), 'HasCoSigner_Yes')]

# %%
# 2) mean importance take col > mean import
mean_imp = sum(dt.feature_importances_)/len(dt.feature_importances_)
X_train.columns[dt.feature_importances_ > mean_imp ]
# Out:
# Index(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'InterestRate', 'DTIRatio'],
#       dtype='object')

# %% [markdown]
# ## APPLY RFE

# %%
from sklearn.feature_selection import RFE
rfe = RFE(dt)
rfe.fit(X_train,y_train)
# Out:
# RFE(estimator=DecisionTreeClassifier(random_state=7))

# %%
for imp,col in sorted(zip(rfe.ranking_,X_train.columns)):
    print(f"{col} = {imp}")
# Out:
# Age = 1
# CreditScore = 1
# DTIRatio = 1
# Education = 1
# HasDependents_No = 1
# HasMortgage_Yes = 1
# Income = 1
# InterestRate = 1
# LoanAmount = 1
# LoanID = 1
# LoanTerm = 1
# MaritalStatus_Divorced = 1
# MonthsEmployed = 1
# NumCreditLines = 1
# EmploymentType_Unemployed = 2
# HasCoSigner_No = 3
# EmploymentType_Part-time = 4
# LoanPurpose_Business = 5
# LoanPurpose_Home = 6
# MaritalStatus_Single = 7
# LoanPurpose_Other = 8
# EmploymentType_Self-employed = 9
# LoanPurpose_Education = 10
# EmploymentType_Full-time = 11
# LoanPurpose_Auto = 12
# HasMortgage_No = 13
# MaritalStatus_Married = 14
# HasDependents_Yes = 15
# HasCoSigner_Yes = 16

# %%
#2) important column rank = 1
print("Column Count = ",len(X_train.columns[rfe.ranking_ == 1  ]))
X_train.columns[rfe.ranking_ == 1 ]
# Out:
# Column Count =  14
# Index(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio', 'Education', 'MaritalStatus_Divorced', 'HasMortgage_Yes',
#        'HasDependents_No'],
#       dtype='object')

# %%
X = df[['Age', 'Income', 'LoanAmount', 'CreditScore','MonthsEmployed','InterestRate','DTIRatio','LoanTerm']]
Y= df['Default']

X.shape,Y.shape
# Out:
# ((255347, 8), (255347,))

# %%
final_df = pd.DataFrame(X, columns=X.columns)
final_df["Default"] = Y

final_df.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  InterestRate  \
# 0   56   85994       50587          520              80         15.23
# 1   69   50432      124440          458              15          4.81
# 2   46   84208      129188          451              26         21.17
# 3   32   31713       44799          743               0          7.07
# 4   60   20437        9139          633               8          6.51
#
#    DTIRatio  LoanTerm  Default
# 0      0.44        36        0
# 1      0.68        60        0
# 2      0.31        24        1
# 3      0.23        24        0
# 4      0.73        48        0

# %%
final_df.shape
# Out:
# (255347, 9)

# %%
final_df.to_csv('Loan_default_Selected_8_features.csv', index=False)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Loan_default_Preprocessing.csv')
df.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio  Education  ...  LoanPurpose_Education  \
# 0         15.23        36      0.44          1  ...                  False
# 1          4.81        60      0.68          2  ...                  False
# 2         21.17        24      0.31          2  ...                  False
# 3          7.07        24      0.23          0  ...                  False
# 4          6.51        48      0.73          1  ...                  False
#
#    LoanPurpose_Home  LoanPurpose_Other  HasMortgage_No  HasMortgage_Yes  \
# 0             False               True           False             True
# 1             False               True            True            False
# 2             False              False           False             True
# 3             False              False            True            False
# 4             False              False            True            False
#
#    HasDependents_No  HasDependents_Yes  HasCoSigner_No  HasCoSigner_Yes  \
# 0             False               True           False             True
# 1              True              False           False             True
# 2             False               True            True            False
# 3              True              False            True            False
# 4             False               True            True            False
#
#    Default
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451388 entries, 0 to 451387
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Age                           451388 non-null  int64
#  1   Income                        451388 non-null  int64
#  2   LoanAmount                    451388 non-null  int64
#  3   CreditScore                   451388 non-null  int64
#  4   MonthsEmployed                451388 non-null  int64
#  5   NumCreditLines                451388 non-null  int64
#  6   InterestRate                  451388 non-null  float64
#  7   LoanTerm                      451388 non-null  int64
#  8   DTIRatio                      451388 non-null  float64
#  9   Education                     451388 non-null  int64
#  10  EmploymentType_Full-time      451388 non-null  bool
#  11  EmploymentType_Part-time      451388 non-null  bool
#  12  EmploymentType_Self-employed  451388 non-null  bool
#  13  EmploymentType_Unemployed     451388 non-null  bool
#  14  MaritalStatus_Divorced        451388 non-null  bool
#  15  MaritalStatus_Married         451388 non-null  bool
#  16  MaritalStatus_Single          451388 non-null  bool
#  17  LoanPurpose_Auto              451388 non-null  bool
#  18  LoanPurpose_Business          451388 non-null  bool
#  19  LoanPurpose_Education         451388 non-null  bool
#  20  LoanPurpose_Home              451388 non-null  bool
#  21  LoanPurpose_Other             451388 non-null  bool
#  22  HasMortgage_No                451388 non-null  bool
#  23  HasMortgage_Yes               451388 non-null  bool
#  24  HasDependents_No              451388 non-null  bool
#  25  HasDependents_Yes             451388 non-null  bool
#  26  HasCoSigner_No                451388 non-null  bool
#  27  HasCoSigner_Yes               451388 non-null  bool
#  28  Default                       451388 non-null  int64
# dtypes: bool(18), float64(2), int64(9)
# memory usage: 45.6 MB

# %%
X=df_ohe.drop('Default',axis=1)
Y=df_ohe['Default']
X.shape , Y.shape
# Out:
# ((255347, 29), (255347,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=7,stratify = Y)

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state = 7)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=7)

# %%
# importance of all features
sorted(zip(dt.feature_importances_,X_train.columns),reverse = True)
# Out:
# [(np.float64(0.1221538187342497), 'Income'),
#  (np.float64(0.12089658671551835), 'LoanAmount'),
#  (np.float64(0.11359213652591019), 'InterestRate'),
#  (np.float64(0.09934763957418692), 'LoanID'),
#  (np.float64(0.09285585242591118), 'CreditScore'),
#  (np.float64(0.08415808780421537), 'MonthsEmployed'),
#  (np.float64(0.07568019955061366), 'DTIRatio'),
#  (np.float64(0.0752965616345267), 'Age'),
#  (np.float64(0.028752039949372712), 'LoanTerm'),
#  (np.float64(0.025425948379092525), 'Education'),
#  (np.float64(0.02475718353670561), 'NumCreditLines'),
#  (np.float64(0.009022231293263136), 'EmploymentType_Unemployed'),
#  (np.float64(0.008703775238067193), 'LoanPurpose_Education'),
#  (np.float64(0.008630803559652019), 'LoanPurpose_Home'),
#  (np.float64(0.008588727352280966), 'EmploymentType_Part-time'),
#  (np.float64(0.008545146029686932), 'LoanPurpose_Business'),
#  (np.float64(0.008508844183329832), 'EmploymentType_Self-employed'),
#  (np.float64(0.008413959228606983), 'LoanPurpose_Auto'),
#  (np.float64(0.008358153360763869), 'LoanPurpose_Other'),
#  (np.float64(0.008074603072087292), 'EmploymentType_Full-time'),
#  (np.float64(0.008038472330665519), 'MaritalStatus_Single'),
#  (np.float64(0.007649090456169132), 'MaritalStatus_Divorced'),
#  (np.float64(0.007159791955919994), 'MaritalStatus_Married'),
#  (np.float64(0.007029638907642977), 'HasMortgage_No'),
#  (np.float64(0.006885058946538381), 'HasDependents_No'),
#  (np.float64(0.006767808893575836), 'HasMortgage_Yes'),
#  (np.float64(0.005690958777937026), 'HasCoSigner_No'),
#  (np.float64(0.0056471878421743855), 'HasDependents_Yes'),
#  (np.float64(0.005369693741335533), 'HasCoSigner_Yes')]

# %%
# 2) mean importance take col > mean import
mean_imp = sum(dt.feature_importances_)/len(dt.feature_importances_)
X_train.columns[dt.feature_importances_ > mean_imp ]
# Out:
# Index(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'InterestRate', 'DTIRatio'],
#       dtype='object')

# %%
from sklearn.feature_selection import RFE
rfe = RFE(dt)
rfe.fit(X_train,y_train)
# Out:
# RFE(estimator=DecisionTreeClassifier(random_state=7))

# %%
for imp,col in sorted(zip(rfe.ranking_,X_train.columns)):
    print(f"{col} = {imp}")
# Out:
# Age = 1
# CreditScore = 1
# DTIRatio = 1
# Education = 1
# HasDependents_No = 1
# HasMortgage_Yes = 1
# Income = 1
# InterestRate = 1
# LoanAmount = 1
# LoanID = 1
# LoanTerm = 1
# MaritalStatus_Divorced = 1
# MonthsEmployed = 1
# NumCreditLines = 1
# EmploymentType_Unemployed = 2
# HasCoSigner_No = 3
# EmploymentType_Part-time = 4
# LoanPurpose_Business = 5
# LoanPurpose_Home = 6
# MaritalStatus_Single = 7
# LoanPurpose_Other = 8
# EmploymentType_Self-employed = 9
# LoanPurpose_Education = 10
# EmploymentType_Full-time = 11
# LoanPurpose_Auto = 12
# HasMortgage_No = 13
# MaritalStatus_Married = 14
# HasDependents_Yes = 15
# HasCoSigner_Yes = 16

# %%
#2) important column rank = 1
print("Column Count = ",len(X_train.columns[rfe.ranking_ == 1  ]))
X_train.columns[rfe.ranking_ == 1 ]
# Out:
# Column Count =  14
# Index(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio', 'Education', 'MaritalStatus_Divorced', 'HasMortgage_Yes',
#        'HasDependents_No'],
#       dtype='object')

# %%
X = df[['Age', 'Income', 'LoanAmount', 'CreditScore','MonthsEmployed','InterestRate','DTIRatio','LoanTerm']]
Y= df['Default']

X.shape,Y.shape
# Out:
# ((451388, 8), (451388,))

# %%
final_df = pd.DataFrame(X, columns=X.columns)
final_df["Default"] = Y

final_df.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  InterestRate  \
# 0   56   85994       50587          520              80         15.23
# 1   69   50432      124440          458              15          4.81
# 2   46   84208      129188          451              26         21.17
# 3   32   31713       44799          743               0          7.07
# 4   60   20437        9139          633               8          6.51
#
#    DTIRatio  LoanTerm  Default
# 0      0.44        36        0
# 1      0.68        60        0
# 2      0.31        24        1
# 3      0.23        24        0
# 4      0.73        48        0

# %%
final_df.to_csv('loan_default_Selected_8_features.csv', index=False)

# %%
X1 = df[['Age', 'Income', 'LoanAmount', 'CreditScore',
       'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
       'DTIRatio', 'Education', 'MaritalStatus_Divorced', 'HasMortgage_Yes',
       'HasDependents_No']]
Y1 = df['Default']

X1.shape,Y1.shape
# Out:
# ((451388, 13), (451388,))

# %%
final_df1 = pd.DataFrame(X1, columns=X1.columns)
final_df1["Default"] = Y1

final_df1.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio  Education  MaritalStatus_Divorced  \
# 0         15.23        36      0.44          1                    True
# 1          4.81        60      0.68          2                   False
# 2         21.17        24      0.31          2                    True
# 3          7.07        24      0.23          0                   False
# 4          6.51        48      0.73          1                    True
#
#    HasMortgage_Yes  HasDependents_No  Default
# 0             True             False        0
# 1            False              True        0
# 2             True             False        1
# 3            False              True        0
# 4            False             False        0

# %%
final_df1.to_csv('loan_default_Selected_13_features.csv', index=False)
